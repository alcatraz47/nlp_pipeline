# %%
import pandas as pd
import numpy as np
import seaborn as sns
import os

# %%
#reading data file
df = pd.read_csv(r"C:\Users\satad\Desktop\food_coded.csv")
Orgdf = df
df
# Out:
#        GPA  Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# 0      2.4       2          1               430           NaN           315.0
# 1    3.654       1          1               610           3.0           420.0
# 2      3.3       1          1               720           4.0           420.0
# 3      3.2       1          1               430           3.0           420.0
# 4      3.5       1          1               720           2.0           420.0
# ..     ...     ...        ...               ...           ...             ...
# 120    3.5       1          1               610           4.0           420.0
# 121      3       1          1               265           2.0           315.0
# 122  3.882       1          1               720           NaN           420.0
# 123      3       2          1               720           4.0           420.0
# 124    3.9       1          1               430           NaN           315.0
#
# ...

# %%
#to display max rows
#pd.set_option('display.max_rows', 125)
#125 can be changed with row number

# %%
#each coloumn description in statistical view point
df.describe()
# Out:
#            Gender   breakfast  calories_chicken  calories_day  calories_scone  \
# count  125.000000  125.000000        125.000000    106.000000      124.000000
# mean     1.392000    1.112000        577.320000      3.028302      505.241935
# std      0.490161    0.316636        131.214156      0.639308      230.840506
# min      1.000000    1.000000        265.000000      2.000000      315.000000
# 25%      1.000000    1.000000        430.000000      3.000000      420.000000
# 50%      1.000000    1.000000        610.000000      3.000000      420.000000
# 75%      2.000000    1.000000        720.000000      3.000000      420.000000
# max      2.000000    2.000000        720.000000      4.000000      980.000000
#
#           coffee  comfort_food_reasons_coded        cook  \
# count  125.00000                  106.000000  122.000000
# mean     1.75200                    2.698113    2.786885
# std      0.43359                    1.972042    1.038351
# ...

# %%
#Checking data types
df.dtypes
# Out:
# GPA                  object
# Gender                int64
# breakfast             int64
# calories_chicken      int64
# calories_day        float64
#                      ...
# type_sports          object
# veggies_day           int64
# vitamins              int64
# waffle_calories       int64
# weight               object
# Length: 61, dtype: object

# %%
#shape of the dataset
df.shape
# Out:
# (125, 61)

# %%
#types of data information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125 entries, 0 to 124
# Data columns (total 61 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   GPA                           123 non-null    object
#  1   Gender                        125 non-null    int64
#  2   breakfast                     125 non-null    int64
#  3   calories_chicken              125 non-null    int64
#  4   calories_day                  106 non-null    float64
#  5   calories_scone                124 non-null    float64
#  6   coffee                        125 non-null    int64
#  7   comfort_food                  124 non-null    object
#  8   comfort_food_reasons          123 non-null    object
#  9   comfort_food_reasons_coded    106 non-null    float64
#  10  cook                          122 non-null    float64
#  11  comfort_food_reasons_coded.1  125 non-null    int64
# ...

# %%
#searching for the sum of the null values
df.isnull().sum()
# Out:
# GPA                  2
# Gender               0
# breakfast            0
# calories_chicken     0
# calories_day        19
#                     ..
# type_sports         26
# veggies_day          0
# vitamins             0
# waffle_calories      0
# weight               2
# Length: 61, dtype: int64

# %%
#sorting values in ascending order
df.isnull().sum(axis=0).sort_values()
# Out:
# fruit_day                      0
# italian_food                   0
# indian_food                    0
# ideal_diet_coded               0
# healthy_feeling                0
#                               ..
# exercise                      13
# cuisine                       17
# comfort_food_reasons_coded    19
# calories_day                  19
# type_sports                   26
# Length: 61, dtype: int64

# %%
#sum of null values in ascending order
df.isnull().sum(axis=0).sort_values(ascending=False)
# Out:
# type_sports                     26
# calories_day                    19
# comfort_food_reasons_coded      19
# cuisine                         17
# exercise                        13
#                                 ..
# comfort_food_reasons_coded.1     0
# diet_current_coded               0
# ethnic_food                      0
# eating_out                       0
# fruit_day                        0
# Length: 61, dtype: int64

# %%
#checking if there are missing values coloumnwise
df.isnull().any()
# Out:
# GPA                  True
# Gender              False
# breakfast           False
# calories_chicken    False
# calories_day         True
#                     ...
# type_sports          True
# veggies_day         False
# vitamins            False
# waffle_calories     False
# weight               True
# Length: 61, dtype: bool

# %%
#coloumn names 
d =df.isnull().any()
d.index
# Out:
# Index(['GPA', 'Gender', 'breakfast', 'calories_chicken', 'calories_day',
#        'calories_scone', 'coffee', 'comfort_food', 'comfort_food_reasons',
#        'comfort_food_reasons_coded', 'cook', 'comfort_food_reasons_coded.1',
#        'cuisine', 'diet_current', 'diet_current_coded', 'drink',
#        'eating_changes', 'eating_changes_coded', 'eating_changes_coded1',
#        'eating_out', 'employment', 'ethnic_food', 'exercise',
#        'father_education', 'father_profession', 'fav_cuisine',
#        'fav_cuisine_coded', 'fav_food', 'food_childhood', 'fries', 'fruit_day',
#        'grade_level', 'greek_food', 'healthy_feeling', 'healthy_meal',
#        'ideal_diet', 'ideal_diet_coded', 'income', 'indian_food',
#        'italian_food', 'life_rewarding', 'marital_status',
#        'meals_dinner_friend', 'mother_education', 'mother_profession',
#        'nutritional_check', 'on_off_campus', 'parents_cook', 'pay_meal_out',
# ...

# %%
#to check the values of the indexces
d.values
# Out:
# array([ True, False, False, False,  True,  True, False,  True,  True,
#         True,  True, False,  True,  True, False,  True,  True, False,
#        False, False,  True, False,  True,  True,  True,  True, False,
#         True,  True, False, False, False, False, False,  True,  True,
#        False,  True, False, False,  True,  True,  True,  True,  True,
#        False,  True, False, False,  True,  True,  True,  True, False,
#         True, False,  True, False, False, False,  True])

# %%
#passing value through indexes to check only true values
d.index[d.values]
# Out:
# Index(['GPA', 'calories_day', 'calories_scone', 'comfort_food',
#        'comfort_food_reasons', 'comfort_food_reasons_coded', 'cook', 'cuisine',
#        'diet_current', 'drink', 'eating_changes', 'employment', 'exercise',
#        'father_education', 'father_profession', 'fav_cuisine', 'fav_food',
#        'food_childhood', 'healthy_meal', 'ideal_diet', 'income',
#        'life_rewarding', 'marital_status', 'meals_dinner_friend',
#        'mother_education', 'mother_profession', 'on_off_campus',
#        'persian_food', 'self_perception_weight', 'soup', 'sports',
#        'tortilla_calories', 'type_sports', 'weight'],
#       dtype='object')

# %%
#to check if in any coloumn all values are missing
df.isnull().all()
# Out:
# GPA                 False
# Gender              False
# breakfast           False
# calories_chicken    False
# calories_day        False
#                     ...
# type_sports         False
# veggies_day         False
# vitamins            False
# waffle_calories     False
# weight              False
# Length: 61, dtype: bool

# %%
#to check if any row all values are missing
df.isnull().all(axis = 1)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 120    False
# 121    False
# 122    False
# 123    False
# 124    False
# Length: 125, dtype: bool

# %%
#selecting first three columns with most null values
col = df.isnull().sum().sort_values(ascending=False).head(3).index.values
col
# Out:
# array(['type_sports', 'calories_day', 'comfort_food_reasons_coded'],
#       dtype=object)

# %%
#dropping the coloumns selected three columns
df = df.drop(col,axis='columns')
df
# Out:
#        GPA  Gender  breakfast  calories_chicken  calories_scone  coffee  \
# 0      2.4       2          1               430           315.0       1
# 1    3.654       1          1               610           420.0       2
# 2      3.3       1          1               720           420.0       2
# 3      3.2       1          1               430           420.0       2
# 4      3.5       1          1               720           420.0       2
# ..     ...     ...        ...               ...             ...     ...
# 120    3.5       1          1               610           420.0       2
# 121      3       1          1               265           315.0       2
# 122  3.882       1          1               720           420.0       1
# 123      3       2          1               720           420.0       1
# 124    3.9       1          1               430           315.0       2
#
#                                 comfort_food  \
# 0                                       none
# ...

# %%
#check in heatmap if there are any null values available
sns.heatmap(df.isnull(), yticklabels = False)
# Out:
# <AxesSubplot:>

# %%
#retaining the rows having more than 5 missing values
df = df[df.isnull().sum(axis=1) <= 5]
df
# Out:
#        GPA  Gender  breakfast  calories_chicken  calories_scone  coffee  \
# 0      2.4       2          1               430           315.0       1
# 1    3.654       1          1               610           420.0       2
# 2      3.3       1          1               720           420.0       2
# 3      3.2       1          1               430           420.0       2
# 4      3.5       1          1               720           420.0       2
# ..     ...     ...        ...               ...             ...     ...
# 120    3.5       1          1               610           420.0       2
# 121      3       1          1               265           315.0       2
# 122  3.882       1          1               720           420.0       1
# 123      3       2          1               720           420.0       1
# 124    3.9       1          1               430           315.0       2
#
#                                 comfort_food  \
# 0                                       none
# ...

# %%
#% of missing data after cleaning
len(df)/len(Orgdf)*100
# Out:
# 46.400000000000006
